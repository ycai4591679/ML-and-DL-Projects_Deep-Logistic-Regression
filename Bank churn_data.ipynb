# %%
#### Importing Libraries ####

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn

# %%
dataset = pd.read_csv('churn_data.csv') # Users who were 60 days enrolled, churn in the next 30

# %%
#### EDA ####


dataset.head(5) # Viewing the Data
dataset.columns
dataset.describe() # Distribution of Numerical Variables
# Out:
#                user         churn           age  credit_score      deposits  \
# count  27000.000000  27000.000000  26996.000000  18969.000000  27000.000000
# mean   35422.702519      0.413852     32.219921    542.944225      3.341556
# std    20321.006678      0.492532      9.964838     61.059315      9.131406
# min        1.000000      0.000000     17.000000      2.000000      0.000000
# 25%    17810.500000      0.000000     25.000000    507.000000      0.000000
# 50%    35749.000000      0.000000     30.000000    542.000000      0.000000
# 75%    53244.250000      1.000000     37.000000    578.000000      1.000000
# max    69658.000000      1.000000     91.000000    838.000000     65.000000
#
#          withdrawal  purchases_partners     purchases      cc_taken  \
# count  27000.000000        27000.000000  27000.000000  27000.000000
# mean       0.307000           28.062519      3.273481      0.073778
# std        1.055416           42.219686      8.953077      0.437299
# min        0.000000            0.000000      0.000000      0.000000
# 25%        0.000000            0.000000      0.000000      0.000000
# 50%        0.000000            9.000000      0.000000      0.000000
# 75%        0.000000           43.000000      1.000000      0.000000
# max       29.000000         1067.000000     63.000000     29.000000
#
#        cc_recommended  ...  registered_phones  waiting_4_loan  cancelled_loan  \
# count    27000.000000  ...       27000.000000    27000.000000    27000.000000
# mean        92.625778  ...           0.420926        0.001296        0.018815
# std         88.869343  ...           0.912831        0.035981        0.135873
# min          0.000000  ...           0.000000        0.000000        0.000000
# 25%         10.000000  ...           0.000000        0.000000        0.000000
# 50%         65.000000  ...           0.000000        0.000000        0.000000
# 75%        164.000000  ...           0.000000        0.000000        0.000000
# max        522.000000  ...           5.000000        1.000000        1.000000
#
#        received_loan  rejected_loan  left_for_two_month_plus  \
# count   27000.000000   27000.000000             27000.000000
# mean        0.018185       0.004889                 0.173444
# std         0.133623       0.069751                 0.378638
# min         0.000000       0.000000                 0.000000
# 25%         0.000000       0.000000                 0.000000
# 50%         0.000000       0.000000                 0.000000
# 75%         0.000000       0.000000                 0.000000
# max         1.000000       1.000000                 1.000000
#
#        left_for_one_month  rewards_earned   reward_rate   is_referred
# count        27000.000000    23773.000000  27000.000000  27000.000000
# mean             0.018074       29.110125      0.907684      0.318037
# std              0.133222       21.973478      0.752016      0.465723
# min              0.000000        1.000000      0.000000      0.000000
# 25%              0.000000        9.000000      0.200000      0.000000
# 50%              0.000000       25.000000      0.780000      0.000000
# 75%              0.000000       48.000000      1.530000      1.000000
# max              1.000000      114.000000      4.000000      1.000000
#
# [8 rows x 28 columns]

# %%
# Cleaning Data
#dataset[dataset.credit_score < 300]
#dataset = dataset[dataset.credit_score >= 300]

# %%
dataset.describe() # Distribution of Numerical Variables
# Out:
#                user         churn           age  credit_score      deposits  \
# count  27000.000000  27000.000000  26996.000000  18969.000000  27000.000000
# mean   35422.702519      0.413852     32.219921    542.944225      3.341556
# std    20321.006678      0.492532      9.964838     61.059315      9.131406
# min        1.000000      0.000000     17.000000      2.000000      0.000000
# 25%    17810.500000      0.000000     25.000000    507.000000      0.000000
# 50%    35749.000000      0.000000     30.000000    542.000000      0.000000
# 75%    53244.250000      1.000000     37.000000    578.000000      1.000000
# max    69658.000000      1.000000     91.000000    838.000000     65.000000
#
#          withdrawal  purchases_partners     purchases      cc_taken  \
# count  27000.000000        27000.000000  27000.000000  27000.000000
# mean       0.307000           28.062519      3.273481      0.073778
# std        1.055416           42.219686      8.953077      0.437299
# min        0.000000            0.000000      0.000000      0.000000
# 25%        0.000000            0.000000      0.000000      0.000000
# 50%        0.000000            9.000000      0.000000      0.000000
# 75%        0.000000           43.000000      1.000000      0.000000
# max       29.000000         1067.000000     63.000000     29.000000
#
#        cc_recommended  ...  registered_phones  waiting_4_loan  cancelled_loan  \
# count    27000.000000  ...       27000.000000    27000.000000    27000.000000
# mean        92.625778  ...           0.420926        0.001296        0.018815
# std         88.869343  ...           0.912831        0.035981        0.135873
# min          0.000000  ...           0.000000        0.000000        0.000000
# 25%         10.000000  ...           0.000000        0.000000        0.000000
# 50%         65.000000  ...           0.000000        0.000000        0.000000
# 75%        164.000000  ...           0.000000        0.000000        0.000000
# max        522.000000  ...           5.000000        1.000000        1.000000
#
#        received_loan  rejected_loan  left_for_two_month_plus  \
# count   27000.000000   27000.000000             27000.000000
# mean        0.018185       0.004889                 0.173444
# std         0.133623       0.069751                 0.378638
# min         0.000000       0.000000                 0.000000
# 25%         0.000000       0.000000                 0.000000
# 50%         0.000000       0.000000                 0.000000
# 75%         0.000000       0.000000                 0.000000
# max         1.000000       1.000000                 1.000000
#
#        left_for_one_month  rewards_earned   reward_rate   is_referred
# count        27000.000000    23773.000000  27000.000000  27000.000000
# mean             0.018074       29.110125      0.907684      0.318037
# std              0.133222       21.973478      0.752016      0.465723
# min              0.000000        1.000000      0.000000      0.000000
# 25%              0.000000        9.000000      0.200000      0.000000
# 50%              0.000000       25.000000      0.780000      0.000000
# 75%              0.000000       48.000000      1.530000      1.000000
# max              1.000000      114.000000      4.000000      1.000000
#
# [8 rows x 28 columns]

# %%
# Removing NaN
dataset.isna().any()
# Out:
# user                       False
# churn                      False
# age                         True
# housing                    False
# credit_score                True
# deposits                   False
# withdrawal                 False
# purchases_partners         False
# purchases                  False
# cc_taken                   False
# cc_recommended             False
# cc_disliked                False
# cc_liked                   False
# cc_application_begin       False
# app_downloaded             False
# web_user                   False
# app_web_user               False
# ios_user                   False
# android_user               False
# registered_phones          False
# payment_type               False
# waiting_4_loan             False
# cancelled_loan             False
# received_loan              False
# rejected_loan              False
# zodiac_sign                False
# left_for_two_month_plus    False
# left_for_one_month         False
# rewards_earned              True
# reward_rate                False
# is_referred                False
# dtype: bool

# %%
dataset.isna().sum()
# Out:
# user                          0
# churn                         0
# age                           4
# housing                       0
# credit_score               8031
# deposits                      0
# withdrawal                    0
# purchases_partners            0
# purchases                     0
# cc_taken                      0
# cc_recommended                0
# cc_disliked                   0
# cc_liked                      0
# cc_application_begin          0
# app_downloaded                0
# web_user                      0
# app_web_user                  0
# ios_user                      0
# android_user                  0
# registered_phones             0
# payment_type                  0
# waiting_4_loan                0
# cancelled_loan                0
# received_loan                 0
# rejected_loan                 0
# zodiac_sign                   0
# left_for_two_month_plus       0
# left_for_one_month            0
# rewards_earned             3227
# reward_rate                   0
# is_referred                   0
# dtype: int64

# %%
sn.heatmap(dataset.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
dataset = dataset.drop(columns = ['credit_score', 'rewards_earned'])
dataset=dataset[pd.notnull(dataset['age'])]

# %%
sn.heatmap(dataset.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
dataset2 = dataset.drop(columns = ['user', 'churn'])

# %%
dataset2.columns
# Out:
# Index(['age', 'housing', 'deposits', 'withdrawal', 'purchases_partners',
#        'purchases', 'cc_taken', 'cc_recommended', 'cc_disliked', 'cc_liked',
#        'cc_application_begin', 'app_downloaded', 'web_user', 'app_web_user',
#        'ios_user', 'android_user', 'registered_phones', 'payment_type',
#        'waiting_4_loan', 'cancelled_loan', 'received_loan', 'rejected_loan',
#        'zodiac_sign', 'left_for_two_month_plus', 'left_for_one_month',
#        'reward_rate', 'is_referred'],
#       dtype='object')

# %%
sn.set_style('darkgrid')
plt.figure(figsize=(20,12))

sn.countplot(x='age',data=dataset2,palette='rainbow')

# %%
## Histograms
sn.set_style('darkgrid')
plt.figure(figsize=(20,12))

plt.suptitle('Histograms of Numerical Columns', fontsize=20)
for i in range(1, dataset2.shape[1] + 1):
    plt.subplot(6, 5, i)
    f = plt.gca()
    f.axes.get_yaxis().set_visible(False)
    f.set_title(dataset2.columns.values[i - 1])

    vals = np.size(dataset2.iloc[:, i - 1].unique())
    
    plt.hist(dataset2.iloc[:, i - 1], bins=vals)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-3f253d402a23> in <module>
#      12     vals = np.size(dataset2.iloc[:, i - 1].unique())
#      13
# ---> 14     plt.hist(dataset2.iloc[:, i - 1], bins=vals)
#      15 plt.tight_layout(rect=[0, 0.03, 1, 0.95])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2634         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2635         color=color, label=label, stacked=stacked, normed=normed,
# -> 2636         **({"data": data} if data is not None else {}), **kwargs)
#    2637
#    2638
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6827                 patch = _barfunc(bins[:-1]+boffset, height, width,
#    6828                                  align='center', log=log,
# -> 6829                                  color=c, **{bottom_kwarg: bottom})
#    6830                 patches.append(patch)
#    6831                 if stacked:
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2436             elif orientation == 'horizontal':
#    2437                 r.sticky_edges.x.append(l)
# -> 2438             self.add_patch(r)
#    2439             patches.append(r)
#    2440
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_patch(self, p)
#    1966         self._set_artist_props(p)
#    1967         if p.get_clip_path() is None:
# -> 1968             p.set_clip_path(self.patch)
#    1969         self._update_patch_limits(p)
#    1970         self.patches.append(p)
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     713             if isinstance(path, Rectangle):
#     714                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 715                                                path.get_transform())
#     716                 self._clippath = None
#     717                 success = True
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in get_transform(self)
#     212         to the :class:`Patch`.
#     213         """
# --> 214         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     215
#     216     def get_data_transform(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     756
#     757     def get_patch_transform(self):
# --> 758         self._update_patch_transform()
#     759         return self._rect_transform
#     760
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in _update_patch_transform(self)
#     735         bbox = transforms.Bbox.from_extents(x0, y0, x1, y1)
#     736         rot_trans = transforms.Affine2D()
# --> 737         rot_trans.rotate_deg_around(x0, y0, self.angle)
#     738         self._rect_transform = transforms.BboxTransformTo(bbox)
#     739         self._rect_transform += rot_trans
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in rotate_deg_around(self, x, y, degrees)
#    1958         # Cast to float to avoid wraparound issues with uint8's
#    1959         x, y = float(x), float(y)
# -> 1960         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    1961
#    1962     def translate(self, tx, ty):
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in translate(self, tx, ty)
#    1970         translate_mtx = np.array(
#    1971             [[1.0, 0.0, tx], [0.0, 1.0, ty], [0.0, 0.0, 1.0]], float)
# -> 1972         self._mtx = np.dot(translate_mtx, self._mtx)
#    1973         self.invalidate()
#    1974         return self
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
## Pie Plots
dataset2 = dataset[['housing', 'is_referred', 'app_downloaded',
                    'web_user', 'app_web_user', 'ios_user',
                    'android_user', 'registered_phones', 'payment_type',
                    'waiting_4_loan', 'cancelled_loan',
                    'received_loan', 'rejected_loan', 'zodiac_sign',
                    'left_for_two_month_plus', 'left_for_one_month', 'is_referred']]
sn.set_style('darkgrid')
plt.figure(figsize=(20,12))
plt.suptitle('Pie Chart Distributions', fontsize=20)
for i in range(1, dataset2.shape[1] + 1):
    plt.subplot(6, 3, i)
    f = plt.gca()
    f.axes.get_yaxis().set_visible(False)
    f.set_title(dataset2.columns.values[i - 1])
   
    values = dataset2.iloc[:, i - 1].value_counts(normalize = True).values
    index = dataset2.iloc[:, i - 1].value_counts(normalize = True).index
    plt.pie(values, labels = index, autopct='%1.1f%%')
    plt.axis('equal')
fig.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
## Exploring Uneven Features
dataset[dataset2.waiting_4_loan == 1].churn.value_counts()
# Out:
# 0    27
# 1     8
# Name: churn, dtype: int64

# %%
dataset[dataset2.cancelled_loan == 1].churn.value_counts()
# Out:
# 1    274
# 0    234
# Name: churn, dtype: int64

# %%
dataset[dataset2.received_loan == 1].churn.value_counts()
# Out:
# 1    292
# 0    199
# Name: churn, dtype: int64

# %%
dataset[dataset2.rejected_loan == 1].churn.value_counts()
# Out:
# 1    107
# 0     25
# Name: churn, dtype: int64

# %%
dataset[dataset2.left_for_one_month == 1].churn.value_counts()
# Out:
# 1    266
# 0    222
# Name: churn, dtype: int64

# %%
## Correlation with Response Variable
dataset2.drop(columns = ['housing', 'payment_type',
                         'registered_phones', 'zodiac_sign']
    ).corrwith(dataset.churn).plot.bar(figsize=(24,10),
              title = 'Correlation with Response variable',
              fontsize = 15, rot = 45,
              grid = True)

# %%
## Correlation Matrix
sn.set(style="white")

# Compute the correlation matrix
corr = dataset.drop(columns = ['user', 'churn']).corr()

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(18, 15))

# Generate a custom diverging colormap
cmap = sn.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sn.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
plt.figure(figsize=(20,12))

sn.heatmap(corr,annot=True,Cmap='coolwarm')

# %%
## Data Preparation
user_identifier = dataset['user']
dataset = dataset.drop(columns = ['user'])

# %%
# One-Hot Encoding
dataset.housing.value_counts()
# Out:
# na    13856
# R     10969
# O      2171
# Name: housing, dtype: int64

# %%
dataset.groupby('housing')['churn'].nunique().reset_index()
# Out:
#   housing  churn
# 0       O      2
# 1       R      2
# 2      na      2

# %%
dataset = pd.get_dummies(dataset)
dataset.columns
# Out:
# Index(['churn', 'age', 'deposits', 'withdrawal', 'purchases_partners',
#        'purchases', 'cc_taken', 'cc_recommended', 'cc_disliked', 'cc_liked',
#        'cc_application_begin', 'app_downloaded', 'web_user', 'app_web_user',
#        'ios_user', 'android_user', 'registered_phones', 'waiting_4_loan',
#        'cancelled_loan', 'received_loan', 'rejected_loan',
#        'left_for_two_month_plus', 'left_for_one_month', 'reward_rate',
#        'is_referred', 'housing_O', 'housing_R', 'payment_type_Bi-Weekly',
#        'payment_type_Monthly', 'payment_type_Semi-Monthly',
#        'payment_type_Weekly', 'zodiac_sign_Aquarius', 'zodiac_sign_Aries',
#        'zodiac_sign_Cancer', 'zodiac_sign_Capricorn', 'zodiac_sign_Gemini',
#        'zodiac_sign_Leo', 'zodiac_sign_Libra', 'zodiac_sign_Pisces',
#        'zodiac_sign_Sagittarius', 'zodiac_sign_Scorpio', 'zodiac_sign_Taurus',
#        'zodiac_sign_Virgo'],
#       dtype='object')

# %%
dataset = dataset.drop(columns = ['housing_na', 'zodiac_sign_na', 'payment_type_na'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-8a70137afa1a> in <module>
# ----> 1 dataset = dataset.drop(columns = ['housing_na', 'zodiac_sign_na', 'payment_type_na'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['housing_na' 'zodiac_sign_na' 'payment_type_na'] not found in axis"

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset.drop(columns = 'churn'), dataset['churn'],
                                                    test_size = 0.2,
                                                    random_state = 0)

# %%
import random

# %%
# Balancing the Training Set
y_train.value_counts()
# Out:
# 0    12656
# 1     8940
# Name: churn, dtype: int64

# %%
# Balancing the Training Set
y_train.value_counts()

pos_index = y_train[y_train.values == 1].index
neg_index = y_train[y_train.values == 0].index

if len(pos_index) > len(neg_index):
    higher = pos_index
    lower = neg_index
else:
    higher = neg_index
    lower = pos_index

random.seed(0)
higher = np.random.choice(higher, size=len(lower))
lower = np.asarray(lower)
new_indexes = np.concatenate((lower, higher))

X_train = X_train.loc[new_indexes,]
y_train = y_train[new_indexes]

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train2 = pd.DataFrame(sc_X.fit_transform(X_train))
X_test2 = pd.DataFrame(sc_X.transform(X_test))
X_train2.columns = X_train.columns.values
X_test2.columns = X_test.columns.values
X_train2.index = X_train.index.values
X_test2.index = X_test.index.values
X_train = X_train2
X_test = X_test2

# %%
# Fitting Model to the Training Set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=0, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Predicting Test Set
y_pred = classifier.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-83-66528fab0af4> in <module>
#       1 # Predicting Test Set
# ----> 2 y_pred = classifier.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     261         if not hasattr(self, 'coef_') or self.coef_ is None:
#     262             raise NotFittedError("This %(name)s instance is not fitted "
# --> 263                                  "yet" % {'name': type(self).__name__})
#     264
#     265         X = check_array(X, accept_sparse='csr')
#
# NotFittedError: This LogisticRegression instance is not fitted yet

# %%
# Evaluating Results
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
cm = confusion_matrix(y_test, y_pred)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6138888888888889

# %%
precision_score(y_test, y_pred) # tp / (tp + fp)
# Out:
# 0.5237185609678446

# %%
recall_score(y_test, y_pred) # tp / (tp + fn)
# Out:
# 0.7363473589973142

# %%
f1_score(y_test, y_pred)
# Out:
# 0.6120930232558139

# %%
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred))

# Applying k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
print("SVM Accuracy: %0.3f (+/- %0.3f)" % (accuracies.mean(), accuracies.std() * 2))
# Out:
# Test Data Accuracy: 0.6139
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Test Data Accuracy: 0.640 (+/- 0.021)

# %%
# Analyzing Coefficients
pd.concat([pd.DataFrame(X_train.columns, columns = ["features"]),
           pd.DataFrame(np.transpose(classifier.coef_), columns = ["coef"])
           ],axis = 1)
# Out:
#                      features      coef
# 0                         age -0.169650
# 1                    deposits -0.015507
# 2                  withdrawal  0.042413
# 3          purchases_partners -0.714143
# 4                   purchases -0.096925
# 5                    cc_taken  0.063391
# 6              cc_recommended  0.066373
# 7                 cc_disliked -0.018025
# 8                    cc_liked  0.003862
# 9        cc_application_begin  0.015748
# 10             app_downloaded -0.005574
# 11                   web_user  0.163583
# 12               app_web_user -0.026670
# 13                   ios_user  0.046061
# 14               android_user -0.017924
# 15          registered_phones  0.096306
# 16             waiting_4_loan -0.027760
# 17             cancelled_loan  0.095167
# 18              received_loan  0.126739
# 19              rejected_loan  0.109121
# 20    left_for_two_month_plus  0.047721
# 21         left_for_one_month  0.044254
# 22                reward_rate -0.187318
# 23                is_referred  0.021872
# 24                  housing_O -0.033146
# 25                  housing_R  0.027256
# 26     payment_type_Bi-Weekly -0.078850
# 27       payment_type_Monthly -0.012917
# 28  payment_type_Semi-Monthly -0.039868
# 29        payment_type_Weekly  0.039890
# 30       zodiac_sign_Aquarius -0.006449
# 31          zodiac_sign_Aries  0.044133
# 32         zodiac_sign_Cancer  0.031035
# 33      zodiac_sign_Capricorn  0.045595
# 34         zodiac_sign_Gemini -0.001353
# 35            zodiac_sign_Leo  0.008310
# 36          zodiac_sign_Libra -0.008290
# 37         zodiac_sign_Pisces  0.052301
# 38    zodiac_sign_Sagittarius -0.007404
# 39        zodiac_sign_Scorpio  0.011551
# 40         zodiac_sign_Taurus  0.001369
# 41          zodiac_sign_Virgo  0.007231

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[1670 1496]
#  [ 589 1645]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.53      0.62      3166
#            1       0.52      0.74      0.61      2234
#
#     accuracy                           0.61      5400
#    macro avg       0.63      0.63      0.61      5400
# weighted avg       0.65      0.61      0.61      5400

# %%
#### Feature Selection ####


## Feature Selection
# Recursive Feature Elimination
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
# Model to Test
classifier = LogisticRegression()

# %%
# Select Best X Features
rfe = RFE(classifier, 20)
rfe = rfe.fit(X_train, y_train)
# Out:
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
X_train.columns[rfe.support_]
# Out:
# [ True False  True  True  True  True  True False False False False  True
#   True  True False  True False  True  True  True  True  True  True False
#  False False  True False False  True False False False  True False False
#  False  True False False False False]
# [ 1 12  1  1  1  1  1 10 21 11 20  1  1  1  9  1  7  1  1  1  1  1  1  8
#   2  5  1 13  4  1 19  3  6  1 23 15 17  1 18 14 22 16]
# Index(['age', 'withdrawal', 'purchases_partners', 'purchases', 'cc_taken',
#        'cc_recommended', 'web_user', 'app_web_user', 'ios_user',
#        'registered_phones', 'cancelled_loan', 'received_loan', 'rejected_loan',
#        'left_for_two_month_plus', 'left_for_one_month', 'reward_rate',
#        'payment_type_Bi-Weekly', 'payment_type_Weekly',
#        'zodiac_sign_Capricorn', 'zodiac_sign_Pisces'],
#       dtype='object')

# %%
# New Correlation Matrix
sn.set(style="white")

# %%
# Compute the correlation matrix
corr = X_train[X_train.columns[rfe.support_]].corr()

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(18, 15))

# Generate a custom diverging colormap
cmap = sn.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sn.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Fitting Model to the Training Set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train[X_train.columns[rfe.support_]], y_train)
# Out:
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Predicting Test Set
y_pred = classifier.predict(X_test[X_train.columns[rfe.support_]])

# %%
# Evaluating Results
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
cm = confusion_matrix(y_test, y_pred)
accuracy_score(y_test, y_pred)
# Out:
# 0.6112962962962963

# %%
precision_score(y_test, y_pred) # tp / (tp + fp)
# Out:
# 0.5214081826831589

# %%
recall_score(y_test, y_pred) # tp / (tp + fn)
# Out:
# 0.7358997314234557

# %%
f1_score(y_test, y_pred)
# Out:
# 0.6103582699090403

# %%
df_cm = pd.DataFrame(cm, index = (1, 0), columns = (1, 0))
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred))
# Out:
# Test Data Accuracy: 0.6113

# %%
# Applying k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier,
                             X = X_train[X_train.columns[rfe.support_]],
                             y = y_train, cv = 10)
print("SVM Accuracy: %0.3f (+/- %0.3f)" % (accuracies.mean(), accuracies.std() * 2))
# Out:
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\caiyi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# SVM Accuracy: 0.641 (+/- 0.018)

# %%
# Analyzing Coefficients
pd.concat([pd.DataFrame(X_train[X_train.columns[rfe.support_]].columns, columns = ["features"]),
           pd.DataFrame(np.transpose(classifier.coef_), columns = ["coef"])
           ],axis = 1)
# Out:
#                    features      coef
# 0                       age -0.172583
# 1                withdrawal  0.046639
# 2        purchases_partners -0.707002
# 3                 purchases -0.106727
# 4                  cc_taken  0.063587
# 5            cc_recommended  0.085311
# 6                  web_user  0.187330
# 7              app_web_user -0.046802
# 8                  ios_user  0.066111
# 9         registered_phones  0.096231
# 10           cancelled_loan  0.092241
# 11            received_loan  0.124002
# 12            rejected_loan  0.110094
# 13  left_for_two_month_plus  0.045609
# 14       left_for_one_month  0.043699
# 15              reward_rate -0.192882
# 16   payment_type_Bi-Weekly -0.051498
# 17      payment_type_Weekly  0.062469
# 18    zodiac_sign_Capricorn  0.041670
# 19       zodiac_sign_Pisces  0.045260

# %%
#### End of Model ####


# Formatting Final Results
final_results = pd.concat([y_test, user_identifier], axis = 1).dropna()
final_results['predicted_churn'] = y_pred
final_results = final_results[['user', 'churn', 'predicted_churn']].reset_index(drop=True)

# %%
final_results
# Out:
#        user  churn  predicted_churn
# 0     61353    1.0                1
# 1     67679    0.0                0
# 2     21269    0.0                0
# 3     69531    0.0                1
# 4     25997    0.0                0
# 5     28827    0.0                0
# 6     58305    1.0                0
# 7      2351    0.0                1
# 8     11790    0.0                1
# 9     46727    0.0                0
# 10    65668    1.0                1
# 11     4664    0.0                0
# 12    41211    0.0                0
# 13    17451    0.0                0
# 14    17599    0.0                0
# 15    41826    1.0                1
# 16    67621    1.0                0
# 17    26736    0.0                1
# 18    39733    1.0                1
# 19    65867    0.0                0
# 20    50736    1.0                0
# 21     3897    1.0                1
# 22    34000    1.0                1
# 23    51830    1.0                1
# 24    33385    1.0                1
# 25    14403    1.0                1
# 26    42157    0.0                0
# 27    48917    1.0                1
# 28    27152    0.0                0
# 29    64314    0.0                1
# ...     ...    ...              ...
# 5370  17615    0.0                0
# 5371  20847    0.0                1
# 5372   4725    1.0                0
# 5373  21396    1.0                1
# 5374  63866    0.0                1
# 5375  17170    1.0                0
# 5376  44859    0.0                1
# 5377  50893    1.0                0
# 5378  51126    0.0                1
# 5379  13595    1.0                0
# 5380  27323    1.0                0
# 5381  53548    0.0                0
# 5382  35861    0.0                1
# 5383  53405    1.0                0
# 5384  63780    1.0                0
# 5385  22943    0.0                1
# 5386  21306    0.0                0
# 5387   3964    0.0                0
# 5388  43218    0.0                0
# 5389  12588    1.0                1
# 5390  63394    0.0                1
# 5391  65004    1.0                1
# 5392   4109    0.0                1
# 5393  68179    1.0                0
# 5394  19540    0.0                1
# 5395  22377    0.0                1
# 5396  24291    1.0                1
# 5397  23740    0.0                1
# 5398  47663    1.0                0
# 5399  52752    1.0                1
#
# [5400 rows x 3 columns]
